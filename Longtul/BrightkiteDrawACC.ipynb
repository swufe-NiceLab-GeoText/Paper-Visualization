# %%
import matplotlib.pyplot as plt

WINDOWS_SIZE = 3

def moving_average(data, window_size):
    """
    计算滑动平均以平滑数据曲线。

    参数:
    - data: 需要平滑的列表。
    - window_size: 滑动窗口的大小（即平均值计算时包含的元素数量）。

    返回:
    - 平滑后的列表。
    """
    smoothed_data = []
    half_window = window_size // 2

    for i in range(len(data)):
        # 定义滑动窗口的边界
        start = max(0, i - half_window)
        end = min(len(data), i + half_window + 1)

        # 计算窗口内元素的平均值
        window_avg = sum(data[start:end]) / (end - start)

        # 将计算的平均值添加到结果列表
        smoothed_data.append(window_avg)

    return smoothed_data

# %%
"""
    适用数据：多模型在分类任务中，准确率（Accuracy@1）随训练轮次（Epoch）变化的数据

    步骤：
    1.加载数据
    2.执行moving_average(data, window_size)
    3.绘制折线图

    配色：
    color='b' 蓝色
    color='g' 绿色
    color='r' 红色
    color='m' 品红色
    color='y' 黄色
    color='c' 青色
    color='orange' 橙色
    color='purple' 紫色
    color='brown' 棕色
    
    示例如下：
"""
# Out:
# "\n    适用数据：多模型在分类任务中，准确率（Accuracy@1）随训练轮次（Epoch）变化的数据\n\n    步骤：\n    1.加载数据\n    2.执行moving_average(data, window_size)\n    3.绘制折线图\n\n    配色：\n    color='b' 蓝色\n    color='g' 绿色\n    color='r' 红色\n    color='m' 品红色\n    color='y' 黄色\n    color='c' 青色\n    color='orange' 橙色\n    color='purple' 紫色\n    color='brown' 棕色\n    \n    示例如下：\n"

# %%
"""
    1.加载数据
    2.执行moving_average(data, window_size)
"""
# 对比实验
S2TUL= [51.55133056640625, 53.95817565917969, 54.04943084716797, 56.2585563659668, 56.623573303222656, 58.34600830078125, 59.6692008972168, 61.889732360839844, 60.5133056640625, 60.76045608520508, 59.58555221557617, 60.54752731323242, 62.3612174987793, 58.71102523803711, 61.133079528808594, 60.42585372924805, 61.14828872680664, 60.41444778442383, 61.36882019042969, 59.68821334838867, 62.50570297241211, 60.76805877685547, 62.376426696777344, 61.55893325805664, 60.30038070678711, 61.422054290771484, 62.07984924316406, 60.52851486206055, 60.273765563964844, 59.35361099243164, 60.1026611328125, 61.205322265625, 61.71102523803711, 60.384029388427734, 60.6692008972168, 60.36882019042969, 61.54752731323242, 60.00760269165039, 59.422054290771484, 60.5361213684082, 61.45627212524414, 61.28517150878906, 62.14448547363281, 61.09885787963867, 59.2585563659668, 62.90494155883789, 59.878326416015625, 61.11406707763672, 60.684410095214844, 60.783267974853516, 60.783267974853516, 61.70342254638672, 60.95817565917969, 59.55893325805664, 61.121673583984375, 61.14448547363281, 59.88212966918945, 60.63117980957031, 62.479087829589844, 61.24334716796875, 61.32319259643555, 61.60456085205078, 61.01520919799805, 61.026615142822266, 61.17110061645508, 60.60076141357422, 61.04182434082031, 61.038021087646484, 60.00760269165039, 62.04562759399414, 60.783267974853516, 59.73384094238281, 60.764259338378906, 60.74524688720703, 61.783267974853516, 60.787071228027344, 61.878326416015625, 60.59695816040039, 61.931556701660156, 61.68821334838867]
S2TUL = moving_average(S2TUL,WINDOWS_SIZE)

LTVAE_Resample = [0.07642954151641455, 0.21495808551491594, 0.3173792909661406, 0.36842598229756945, 0.4115552849716667, 0.45183065611389506, 0.4744972603381258, 0.5033924975413291, 0.5203924507095021, 0.5365025991663934, 0.5508331382007212, 0.5616512902168314, 0.570034187233644, 0.5812738256919402, 0.5938247553037044, 0.5949018873226244, 0.5936374279960661, 0.60295696155107, 0.6110588676064254, 0.6089514353954948, 0.6132131316442654, 0.6132131316442654, 0.6183178007774083, 0.6169128459701213, 0.6219706832763546, 0.6264197068327635, 0.6241249473141947, 0.6223453378916312, 0.6263260431789444, 0.6278246616400506, 0.6257640612560296, 0.6313838804851777, 0.6286676345244228, 0.6300257575048003, 0.6339596309652039, 0.6360670631761345, 0.6342406219266613, 0.6351304266379432, 0.6350835948110336, 0.634053294619023, 0.6376593452910598, 0.6351772584648527, 0.6349899311572145, 0.6373783543296023, 0.6358329040415867, 0.636441717791411, 0.6393452910598042, 0.6332103217346509, 0.638830140963799, 0.6387364773099798, 0.6360202313492249, 0.6376125134641503, 0.6374720179834216, 0.6344747810612091, 0.6377061771179694, 0.6393452910598042, 0.6380808317332459, 0.6394857865405329, 0.6417805460591017, 0.6358797358684962, 0.6376593452910598, 0.6360202313492249, 0.6398136093288999, 0.6390174682714372, 0.639579450194352, 0.6404692549056339, 0.6396731138481712, 0.6392047955790755, 0.6366758769259588, 0.6384086545216129, 0.6396731138481712, 0.6416868824052826, 0.6430918372125697, 0.6394389547136233, 0.6409844050016391, 0.6405160867325435, 0.6391111319252564, 0.6399541048096286, 0.6361607268299536, 0.6412653959630965]

LTVAE_Resample=  moving_average(LTVAE_Resample,WINDOWS_SIZE)

# %%
# 使用列表推导式将每个元素增大100倍
LTVAE = [x * 100 for x in LTVAE]
# TULDeep = [x * 100 for x in TULDeep]
# AttnTUL = [x * 100 for x in AttnTUL]
# MainTUL = [x * 100 for x in MainTUL]
LTVAE_NOLaVAE = [x * 100 for x in LTVAE_NOLaVAE]
LTVAE_NOResampledata = [x * 100 for x in LTVAE_NOResampledata]
LTVAE_NORewightingLoss = [x * 100 for x in LTVAE_NORewightingLoss]
# TULBILSTM = [x * 100 for x in TULBILSTM]
# TULLSTM = [x * 100 for x in TULLSTM]
# TULGRU = [x * 100 for x in TULGRU]
TULVAE = [x * 100 for x in TULVAE]
LTVAE_VAE = [x * 100 for x in LTVAE_VAE]
LTVAE_ReweightingLoss = [x * 100 for x in LTVAE_ReweightingLoss]
LTVAE_Resample = [x * 100 for x in LTVAE_Resample]


fig, ax = plt.subplots(figsize=(8, 6))  # 将宽度增大以适应新数据
# 生成x轴的数据，这里我们使用索引作为x轴的数据
x = list(range(len(LTVAE)))  # 或者 len(data2)，因为假设两个数据集长度相同

"""
    3.绘制折线图
    为每个数组分配不同的标记、线型和可选的颜色
"""
# # 绘制折线图
# 为每个数组分配不同的标记、线型和可选的颜色
# plt.plot(x, MainTUL, label='MainTUL', marker='s', linestyle='--', color='r')
# # plt.plot(x, AttnTUL, label='AttnTUL', marker='^', linestyle='-.', color='g')
plt.plot(x, S2TUL, label='S2TUL', marker='o', linestyle='-', color='b')  # 蓝色
plt.plot(x, TULVAE, label='TULVAE', marker='*', linestyle=':', color='g')  # 绿色
plt.plot(x, TULGRU, label='TULGRU', marker='D', linestyle='-', color='r')  # 红色
plt.plot(x, TULLSTM, label='TULLSTM', marker='p', linestyle='--', color='m')  # 品红色
plt.plot(x, TULBILSTM, label='TULBILSTM', marker='h', linestyle='-.', color='y')  # 黄色
plt.plot(x, LTVAE, label='LTVAE', marker='H', linestyle=':', color='c')  # 青色
plt.plot(x, LTVAE_NORewightingLoss, label='LTVAE_NORewightingLoss', marker='x', linestyle=':', color='orange')  # 橙色
plt.plot(x, LTVAE_NOResampledata, label='LTVAE_NOResampledata', marker='v', linestyle=':', color='purple')  # 紫色
plt.plot(x, LTVAE_NOLaVAE, label='LTVAE_NOLaVAE', marker='+', linestyle=':', color='brown')  # 棕色

# 对比实验
plt.plot(x, S2TUL, label='S2TUL', linestyle='-', color='orange')  # 橙色
plt.plot(x, TULDeep, label='TULDeep', linestyle='-', color='purple')  # 紫色
plt.plot(x, MainTUL, label='MainTUL', linestyle='-', color='brown')  # 棕色
plt.plot(x, AttnTUL, label='AttnTUL', linestyle='-', color='b')  # 蓝色
plt.plot(x, TULVAE, label='TULVAE', linestyle='-', color='g')  # 绿色
plt.plot(x, TULGRU, label='TULGRU', linestyle='-', color='r')  # 红色
plt.plot(x, TULLSTM, label='TULLSTM', linestyle='-', color='m')  # 品红色
plt.plot(x, TULBILSTM, label='TULBILSTM', linestyle='-', color='y')  # 黄色
# 主实验
plt.plot(x, LTVAE, label='LongTUL', linestyle='-', color='c')  # 青色
# 消融实验
plt.plot(x, LTVAE_NOResampledata, label='LongTUL w/o C ', linestyle='-', color='orange')  # 橙色
plt.plot(x, LTVAE_NOLaVAE, label='LongTUL w/o P ', linestyle='-', color='brown')  # 棕色
plt.plot(x, LTVAE_NORewightingLoss, label='LongTUL w/o R', linestyle='-', color='purple')  # 紫色
plt.plot(x, LTVAE_ReweightingLoss, label='LongTUL w/o CP', linestyle='-', color='m')  # 品红色
plt.plot(x, LTVAE_VAE, label='LongTUL w/o CR ', linestyle='-', color='b')  # 蓝色
plt.plot(x, LTVAE_Resample, label='LongTUL w/o PR ', linestyle='-', color='r')  # 红色
plt.plot(x, TULVAE, label='LongTUL w/o CPR', linestyle='-', color='g')  # 绿色

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# # 清除X轴的刻度标签
# plt.xticks([])

# 添加图例
# plt.legend(fontsize=20)
plt.legend(fontsize=20, ncol=1)

# 添加标题和轴标签
plt.title('Brightkite',fontsize=30)
plt.xlabel('Epoch',fontsize=30)
plt.ylabel('Accuracy@1',fontsize=30)

# 调整坐标轴刻度大小
plt.tick_params(axis='both', which='major', labelsize=18)



# 显示网格
plt.grid(False)

# 使用 tight_layout() 函数减少空白部分
plt.tight_layout()

# 保存图形
plt.savefig('Brightkite Comparasion ACC New.pdf', format='pdf', bbox_inches='tight')
# plt.savefig('Brightkite Ablation ACC.pdf', format='pdf', bbox_inches='tight')

# 显示图形
plt.show()
# Out:
# C:\Users\86198\AppData\Local\Temp\ipykernel_2324\2812627202.py:83: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
